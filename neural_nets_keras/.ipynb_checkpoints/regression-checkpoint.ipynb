# %% [markdown]
# <a href="https://colab.research.google.com/github/davestroud/Deep_Learning/blob/master/neural_nets_keras/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building a Regression MLP using the Sequential API

# %%
# Import tensorflow and keras
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# We are using tensorflow version 2.0
tf.__version__
# Out:
# '1.15.0-rc3'

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(1)
])
model.compile(loss="mean_squared_error", optimizer="sgd")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
X_new = X_test[:3] # pretend these are new instances
y_pred = model.predict(X_new)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.7835 - val_loss: 1.7322
# Epoch 2/20
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.7525 - val_loss: 0.5198
# Epoch 3/20
# 11610/11610 [==============================] - 0s 37us/sample - loss: 0.4510 - val_loss: 0.4605
# Epoch 4/20
# 11610/11610 [==============================] - 0s 37us/sample - loss: 0.4296 - val_loss: 0.4513
# Epoch 5/20
# 11610/11610 [==============================] - 0s 38us/sample - loss: 0.4210 - val_loss: 0.4341
# Epoch 6/20
# 11610/11610 [==============================] - 0s 38us/sample - loss: 0.4052 - val_loss: 0.4264
# Epoch 7/20
# 11610/11610 [==============================] - 0s 38us/sample - loss: 0.3977 - val_loss: 0.4181
# Epoch 8/20
# 11610/11610 [==============================] - 0s 37us/sample - loss: 0.3913 - val_loss: 0.4105
# Epoch 9/20
# 11610/11610 [==============================] - 0s 38us/sample - loss: 0.3898 - val_loss: 0.4112
# Epoch 10/20
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3844 - val_loss: 0.4059
# Epoch 11/20
# 11610/11610 [==============================] - 0s 38us/sample - loss: 0.3816 - val_loss: 0.4056
# Epoch 12/20
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3778 - val_loss: 0.4062
# Epoch 13/20
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3777 - val_loss: 0.4150
# Epoch 14/20
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3887 - val_loss: 0.3937
# Epoch 15/20
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3912 - val_loss: 0.4071
# Epoch 16/20
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3728 - val_loss: 0.4126
# Epoch 17/20
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3728 - val_loss: 0.3987
# Epoch 18/20
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.3680 - val_loss: 0.3921
# Epoch 19/20
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3670 - val_loss: 0.4137
# Epoch 20/20
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3677 - val_loss: 0.4105
# 5160/5160 [==============================] - 0s 19us/sample - loss: 0.3652

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.Model(inputs=[input_], outputs=[output])

# %%
input_A = keras.layers.Input(shape=[5], name="wide_input")
input_B = keras.layers.Input(shape=[6], name="deep_input")
hidden1 = keras.layers.Dense(30, activation="relu")(input_B)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1, name="output")(concat)
model = keras.Model(inputs=[input_A, input_B], outputs=[output])

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(lr=1e-3))

X_train_A, X_train_B = X_train[:, :5], X_train[:, 2:]
X_valid_A, X_valid_B = X_valid[:, :5], X_valid[:, 2:]
X_test_A, X_test_B = X_test[:, :5], X_test[:, 2:]
X_new_A, X_new_B = X_test_A[:3], X_test_B[:3]

history = model.fit((X_train_A, X_train_B), y_train, epochs=20,
                    validation_data=((X_valid_A, X_valid_B), y_valid))
mse_test = model.evaluate((X_test_A, X_test_B), y_test)
y_pred = model.predict((X_new_A, X_new_B))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 1s 102us/sample - loss: 1.8356 - val_loss: 0.7821
# Epoch 2/20
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.6364 - val_loss: 0.5667
# Epoch 3/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.5419 - val_loss: 0.5252
# Epoch 4/20
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.5043 - val_loss: 0.5051
# Epoch 5/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4819 - val_loss: 0.4794
# Epoch 6/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4666 - val_loss: 0.4630
# Epoch 7/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4556 - val_loss: 0.4545
# Epoch 8/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4468 - val_loss: 0.4502
# Epoch 9/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4402 - val_loss: 0.4407
# Epoch 10/20
# 11610/11610 [==============================] - 1s 59us/sample - loss: 0.4346 - val_loss: 0.4373
# Epoch 11/20
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.4297 - val_loss: 0.4220
# Epoch 12/20
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.4262 - val_loss: 0.4225
# Epoch 13/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4227 - val_loss: 0.4227
# Epoch 14/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4199 - val_loss: 0.4195
# Epoch 15/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4173 - val_loss: 0.4104
# Epoch 16/20
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.4151 - val_loss: 0.4125
# Epoch 17/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4128 - val_loss: 0.4055
# Epoch 18/20
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.4109 - val_loss: 0.4058
# Epoch 19/20
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.4092 - val_loss: 0.4066
# Epoch 20/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4072 - val_loss: 0.4045
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
[...] # Same as above, up to the main output layer
output = keras.layers.Dense(1, name="main_output")(concat)
aux_output = keras.layers.Dense(1, name="aux_output")(hidden2)
model = keras.Model(inputs=[input_A, input_B], outputs=[output, aux_output])

# %%
model.compile(loss=["mse", "mse"], loss_weights=[0.9, 0.1], optimizer="sgd")

# %%
history = model.fit(
    [X_train_A, X_train_B], [y_train, y_train], epochs=20,
    validation_data=([X_valid_A, X_valid_B], [y_valid, y_valid]))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 2s 132us/sample - loss: 0.6747 - main_output_loss: 0.5763 - aux_output_loss: 1.5580 - val_loss: 0.4827 - val_main_output_loss: 0.4447 - val_aux_output_loss: 0.8253
# Epoch 2/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4537 - main_output_loss: 0.4191 - aux_output_loss: 0.7642 - val_loss: 0.4275 - val_main_output_loss: 0.3990 - val_aux_output_loss: 0.6837
# Epoch 3/20
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4301 - main_output_loss: 0.4043 - aux_output_loss: 0.6649 - val_loss: 0.4288 - val_main_output_loss: 0.4063 - val_aux_output_loss: 0.6321
# Epoch 4/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4174 - main_output_loss: 0.3951 - aux_output_loss: 0.6191 - val_loss: 0.4153 - val_main_output_loss: 0.3947 - val_aux_output_loss: 0.6010
# Epoch 5/20
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4106 - main_output_loss: 0.3903 - aux_output_loss: 0.5951 - val_loss: 0.4017 - val_main_output_loss: 0.3818 - val_aux_output_loss: 0.5808
# Epoch 6/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4117 - main_output_loss: 0.3926 - aux_output_loss: 0.5829 - val_loss: 0.4233 - val_main_output_loss: 0.4050 - val_aux_output_loss: 0.5889
# Epoch 7/20
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.4064 - main_output_loss: 0.3886 - aux_output_loss: 0.5686 - val_loss: 0.3995 - val_main_output_loss: 0.3812 - val_aux_output_loss: 0.5651
# Epoch 8/20
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3958 - main_output_loss: 0.3782 - aux_output_loss: 0.5553 - val_loss: 0.3961 - val_main_output_loss: 0.3766 - val_aux_output_loss: 0.5722
# Epoch 9/20
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3942 - main_output_loss: 0.3767 - aux_output_loss: 0.5509 - val_loss: 0.3930 - val_main_output_loss: 0.3757 - val_aux_output_loss: 0.5495
# Epoch 10/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3896 - main_output_loss: 0.3726 - aux_output_loss: 0.5426 - val_loss: 0.3876 - val_main_output_loss: 0.3699 - val_aux_output_loss: 0.5475
# Epoch 11/20
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3862 - main_output_loss: 0.3695 - aux_output_loss: 0.5363 - val_loss: 0.3812 - val_main_output_loss: 0.3634 - val_aux_output_loss: 0.5417
# Epoch 12/20
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3826 - main_output_loss: 0.3662 - aux_output_loss: 0.5297 - val_loss: 0.3949 - val_main_output_loss: 0.3798 - val_aux_output_loss: 0.5310
# Epoch 13/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3849 - main_output_loss: 0.3694 - aux_output_loss: 0.5246 - val_loss: 0.3935 - val_main_output_loss: 0.3783 - val_aux_output_loss: 0.5303
# Epoch 14/20
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3829 - main_output_loss: 0.3680 - aux_output_loss: 0.5175 - val_loss: 0.3940 - val_main_output_loss: 0.3803 - val_aux_output_loss: 0.5181
# Epoch 15/20
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3797 - main_output_loss: 0.3648 - aux_output_loss: 0.5140 - val_loss: 0.3836 - val_main_output_loss: 0.3677 - val_aux_output_loss: 0.5273
# Epoch 16/20
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3747 - main_output_loss: 0.3597 - aux_output_loss: 0.5085 - val_loss: 0.3862 - val_main_output_loss: 0.3723 - val_aux_output_loss: 0.5124
# Epoch 17/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3718 - main_output_loss: 0.3574 - aux_output_loss: 0.5024 - val_loss: 0.3767 - val_main_output_loss: 0.3607 - val_aux_output_loss: 0.5213
# Epoch 18/20
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3706 - main_output_loss: 0.3565 - aux_output_loss: 0.4979 - val_loss: 0.3807 - val_main_output_loss: 0.3677 - val_aux_output_loss: 0.4982
# Epoch 19/20
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3671 - main_output_loss: 0.3533 - aux_output_loss: 0.4910 - val_loss: 0.3781 - val_main_output_loss: 0.3648 - val_aux_output_loss: 0.4986
# Epoch 20/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3695 - main_output_loss: 0.3558 - aux_output_loss: 0.4919 - val_loss: 0.3716 - val_main_output_loss: 0.3570 - val_aux_output_loss: 0.5042
